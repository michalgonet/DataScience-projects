# %% [markdown]
# based on: https://www.youtube.com/watch?v=e1zKFSrKeLs
#
# # India Census 2011  Dataset
# The Dataset about population, demography, literacy, districs, states, workers, religion, education, age
#
# This data is in CVS and it is analyzed using Pandas DataFrame

# %%
import pandas as pd
pd.set_option('display.expand_frame_repr', False) # for showing width of the colums better

# %%
data = pd.read_csv("india_census_dataset.csv")

# %%
data.head(5)
# Out:
#    District_code         State_name District_name  Population    Male  Female  Literate  Workers  Male_Workers  Female_Workers  ...  Christians  Sikhs  Buddhists  Jains  Secondary_Education  Higher_Education  Graduate_Education  Age_Group_0_29  Age_Group_30_49  Age_Group_50
# 0              1  JAMMU AND KASHMIR       Kupwara      870354  474190  396164    439654   229064        190899           38165  ...        1700   5600         66     39                74948             39709               21751          600759           178435         89679
# 1              2  JAMMU AND KASHMIR        Badgam      753745  398041  355704    335649   214866        162578           52288  ...        1489   5559         47      6                66459             41367               27950          503223           160933         88978
# ...

# %% [markdown]
# ### **Q1) Hide indices of the dataframe.**

# %%
data.head(1)
# Out:
#    District_code         State_name District_name  Population    Male  Female  Literate  Workers  Male_Workers  Female_Workers  ...  Christians  Sikhs  Buddhists  Jains  Secondary_Education  Higher_Education  Graduate_Education  Age_Group_0_29  Age_Group_30_49  Age_Group_50
# 0              1  JAMMU AND KASHMIR       Kupwara      870354  474190  396164    439654   229064        190899           38165  ...        1700   5600         66     39                74948             39709               21751          600759           178435         89679
#
# [1 rows x 25 columns]

# %%
# data.style.hide()

# %% [markdown]
# ### **Q2) How to set the caption/heading on the dataframe.**

# %%
# data.style.set_caption('India Census 2011 Dataset')

# %% [markdown]
# ### **Q3) Show the records related with the disctricts = New Delhi, Lucknow, Jaipur.**

# %%
data.head(1)
# Out:
#    District_code         State_name District_name  Population    Male  Female  Literate  Workers  Male_Workers  Female_Workers  ...  Christians  Sikhs  Buddhists  Jains  Secondary_Education  Higher_Education  Graduate_Education  Age_Group_0_29  Age_Group_30_49  Age_Group_50
# 0              1  JAMMU AND KASHMIR       Kupwara      870354  474190  396164    439654   229064        190899           38165  ...        1700   5600         66     39                74948             39709               21751          600759           178435         89679
#
# [1 rows x 25 columns]

# %%
data[data["District_name"].isin(["New Delhi","Lucknow","Jaipur"])]
# Out:
#      District_code     State_name District_name  Population     Male   Female  Literate  Workers  Male_Workers  Female_Workers  ...  Christians  Sikhs  Buddhists  Jains  Secondary_Education  Higher_Education  Graduate_Education  Age_Group_0_29  Age_Group_30_49  Age_Group_50
# 93              94   NCT OF DELHI     New Delhi      142004    77942    64062    114179    59541         46940           12601  ...        4852   2933        312    679                15942             17742               23934           76076            43913         21773
# 109            110      RAJASTHAN        Jaipur     6626178  3468507  3157671   4300965  2464893       1714947          749946  ...       12708  18782       1020  81079               659389            455527              703673         4091148          1646480        884057
# ...

# %% [markdown]
# ### **Q4) Calcualte state-wise:**
# 1). Total number of population

# %%
data.groupby("State_name").Population.sum().sort_values(ascending=False)
# Out:
# State_name
# UTTAR PRADESH                  199812341
# MAHARASHTRA                    112374333
# BIHAR                          104099452
# WEST BENGAL                     91276115
# ANDHRA PRADESH                  84580777
# MADHYA PRADESH                  72626809
# TAMIL NADU                      72147030
# RAJASTHAN                       68548437
# KARNATAKA                       61095297
# GUJARAT                         60439692
# ORISSA                          41974218
# KERALA                          33406061
# JHARKHAND                       32988134
# ASSAM                           31205576
# PUNJAB                          27743338
# CHHATTISGARH                    25545198
# HARYANA                         25351462
# NCT OF DELHI                    16787941
# JAMMU AND KASHMIR               12541302
# UTTARAKHAND                     10086292
# HIMACHAL PRADESH                 6864602
# TRIPURA                          3673917
# ...

# %% [markdown]
# 2). Total number of population with different religions

# %%
data.columns
# Out:
# Index(['District_code', 'State_name', 'District_name', 'Population', 'Male',
#        'Female', 'Literate', 'Workers', 'Male_Workers', 'Female_Workers',
#        'Cultivator_Workers', 'Agricultural_Workers', 'Household_Workers',
#        'Hindus', 'Muslims', 'Christians', 'Sikhs', 'Buddhists', 'Jains',
#        'Secondary_Education', 'Higher_Education', 'Graduate_Education',
#        'Age_Group_0_29', 'Age_Group_30_49', 'Age_Group_50'],
#       dtype='object')

# %%
religions = ['Hindus', 'Muslims', 'Christians', 'Sikhs', 'Buddhists', 'Jains']
data.groupby('State_name')[religions].sum().sort_values(by= 'Hindus')
# Out:
#                                 Hindus   Muslims  Christians     Sikhs  Buddhists    Jains
# State_name
# LAKSHADWEEP                       1788     62268         317         8         10       11
# MIZORAM                          30136     14832      956331       286      93411      376
# NAGALAND                        173054     48963     1739651      1890       6759     2655
# DAMAN AND DIU                   220150     19277        2820       172        217      287
# ANDAMAN AND NICOBAR ISLANDS     264296     32413       80984      1286        338       31
# DADRA AND NAGAR HAVELI          322857     12922        5113       217        634     1186
# MEGHALAYA                       342078    130399     2213027      3045       9864      627
# SIKKIM                          352662      9867       60522      1868     167216      314
# ARUNACHAL PRADESH               401876     27045      418732      3287     162815      771
# ...

# %% [markdown]
# ### **Q5) How many Male Workers were there in Maharashtra state:**

# %%
data.head(1)
# Out:
#    District_code         State_name District_name  Population    Male  Female  Literate  Workers  Male_Workers  Female_Workers  ...  Christians  Sikhs  Buddhists  Jains  Secondary_Education  Higher_Education  Graduate_Education  Age_Group_0_29  Age_Group_30_49  Age_Group_50
# 0              1  JAMMU AND KASHMIR       Kupwara      870354  474190  396164    439654   229064        190899           38165  ...        1700   5600         66     39                74948             39709               21751          600759           178435         89679
#
# [1 rows x 25 columns]

# %%
data[data["State_name"] == "MAHARASHTRA"]["Male_Workers"].sum()
# Out:
# 32616875

# %% [markdown]
# ### **Q6) How to set a column as index of the dataframe**

# %%
# data.set_index('District_code')

# %% [markdown]
# ### **Q7) How to add a suffix to the column names**

# %%
# data.add_suffix('_suffix')

# %% [markdown]
# ### **Q8) How to add a prefix to the column names**

# %%
# data.add_prefix('prefix_')
